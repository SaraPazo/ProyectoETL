# %% [markdown]
# ## Data viajeros: archivo .csv

# %% [markdown]
# Como segunda fuente he decididio escoger la web del 'INE', de la que me he descargado un archivo .csv sobre la ocupación hotelera, en establecimientos hoteleros en la Comunidad de Madrid.
#
# He decidido acotar mis datos a los últimos tres años. A pesar de que el primero de ellos puede no resultar demasiado representativo, ya que coinciden varias épocas clave con nuevas olas de contagios de COVID-19.
#
#
# En cuanto al proceso de limpieza que se lleva a cabo, decido dividir la tabla inicial en dos tablas diferentes, mostrando en una los 'Residentes' en España y en la otra los 'No Residentes'.
#
# Mis tablas finales constarán de las siguientes columnas:
# Comunidad Autónoma	Residencia	Viajeros	Pernoctaciones	año	mes	Total
# - Comunidad Autónoma
# - Residencia
# - Viajeros
# - Pernoctaciones
# - Año
# - Mes
# - Total: cuenta el total de personas que en ese mes están en un hotel

# %% [markdown]
# url utilizada: https://www.ine.es/jaxiT3/Datos.htm?t=2074

# %% [markdown]
# Para comenzar con la limpieza, importo las librerías que necesito, y aquellas funciones que pueden ser útiles en mi búsqueda.

# %%
import pandas as pd
import numpy as np
import statistics as stats

import warnings
warnings.filterwarnings('ignore')

import pylab as plt
import seaborn as sns

# %%
data = pd.read_csv('../Data/CollectedOnline/Viajeros.csv', sep=';')
data
# Out:
#                                                                                                             Viajeros
# Totales Territoriales Comunidad Autónoma      Viajeros o pernoctaciones Residencia                  Periodo    Total
# Total Nacional        13 Madrid, Comunidad de Viajero                   Residentes en España        2023M09  564.048
#                                                                                                     2023M08  467.045
#                                                                                                     2023M07  563.343
#                                                                                                     2023M06  615.313
# ...                                                                                                              ...
#                                               Pernoctaciones            Residentes en el Extranjero 2021M01  109.984
#                                                                                                     2020M12  113.179
#                                                                                                     2020M11  102.407
#                                                                                                     2020M10  110.247
#                                                                                                     2020M09  128.843
#
# [149 rows x 1 columns]

# %% [markdown]
# **1. PRIMER PASO:**
# - Cambio el nombre de las columnas, en este caso serán los datos de la fila con index=2.
# - Se eliminan las filas que no son útiles.
# - Reseteo el index (y elimino la columna que se ha creado cuando reseteo el index).

# %%
data.reset_index(inplace=True)

# %%
nombres_viejos = data.columns
nombres_viejos
# Out:
# Index(['level_0', 'level_1', 'level_2', 'level_3', 'level_4', 'Viajeros'], dtype='object')

# %%
nombres_nuevos = list(data.iloc[0,:])
nombres_nuevos
# Out:
# ['Totales Territoriales',
#  'Comunidad Autónoma',
#  'Viajeros o pernoctaciones',
#  'Residencia',
#  'Periodo',
#  'Total']

# %%
rename_dict = dict(zip(nombres_viejos,nombres_nuevos))
rename_dict
# Out:
# {'level_0': 'Totales Territoriales',
#  'level_1': 'Comunidad Autónoma',
#  'level_2': 'Viajeros o pernoctaciones',
#  'level_3': 'Residencia',
#  'level_4': 'Periodo',
#  'Viajeros': 'Total'}

# %%
data.rename(columns=rename_dict,inplace=True)

# %%
data.iloc[1:,:]
# Out:
#     Totales Territoriales       Comunidad Autónoma Viajeros o pernoctaciones  \
# 1          Total Nacional  13 Madrid, Comunidad de                   Viajero
# 2          Total Nacional  13 Madrid, Comunidad de                   Viajero
# 3          Total Nacional  13 Madrid, Comunidad de                   Viajero
# 4          Total Nacional  13 Madrid, Comunidad de                   Viajero
# 5          Total Nacional  13 Madrid, Comunidad de                   Viajero
# ..                    ...                      ...                       ...
# 144        Total Nacional  13 Madrid, Comunidad de            Pernoctaciones
# 145        Total Nacional  13 Madrid, Comunidad de            Pernoctaciones
# 146        Total Nacional  13 Madrid, Comunidad de            Pernoctaciones
# 147        Total Nacional  13 Madrid, Comunidad de            Pernoctaciones
# 148        Total Nacional  13 Madrid, Comunidad de            Pernoctaciones
#
#                       Residencia  Periodo    Total
# 1           Residentes en España  2023M09  564.048
# 2           Residentes en España  2023M08  467.045
# 3           Residentes en España  2023M07  563.343
# 4           Residentes en España  2023M06  615.313
# 5           Residentes en España  2023M05  567.870
# ..                           ...      ...      ...
# 144  Residentes en el Extranjero  2021M01  109.984
# 145  Residentes en el Extranjero  2020M12  113.179
# 146  Residentes en el Extranjero  2020M11  102.407
# 147  Residentes en el Extranjero  2020M10  110.247
# 148  Residentes en el Extranjero  2020M09  128.843
#
# [148 rows x 6 columns]

# %%
data = data.iloc[1:,:]

# %%
data.head()
# Out:
#   Totales Territoriales       Comunidad Autónoma Viajeros o pernoctaciones  \
# 1        Total Nacional  13 Madrid, Comunidad de                   Viajero
# 2        Total Nacional  13 Madrid, Comunidad de                   Viajero
# 3        Total Nacional  13 Madrid, Comunidad de                   Viajero
# 4        Total Nacional  13 Madrid, Comunidad de                   Viajero
# 5        Total Nacional  13 Madrid, Comunidad de                   Viajero
#
#              Residencia  Periodo    Total
# 1  Residentes en España  2023M09  564.048
# 2  Residentes en España  2023M08  467.045
# 3  Residentes en España  2023M07  563.343
# 4  Residentes en España  2023M06  615.313
# 5  Residentes en España  2023M05  567.870

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index Totales Territoriales       Comunidad Autónoma  \
# 0      1        Total Nacional  13 Madrid, Comunidad de
# 1      2        Total Nacional  13 Madrid, Comunidad de
# 2      3        Total Nacional  13 Madrid, Comunidad de
# 3      4        Total Nacional  13 Madrid, Comunidad de
# 4      5        Total Nacional  13 Madrid, Comunidad de
#
#   Viajeros o pernoctaciones            Residencia  Periodo    Total
# 0                   Viajero  Residentes en España  2023M09  564.048
# 1                   Viajero  Residentes en España  2023M08  467.045
# 2                   Viajero  Residentes en España  2023M07  563.343
# 3                   Viajero  Residentes en España  2023M06  615.313
# 4                   Viajero  Residentes en España  2023M05  567.870

# %%
data.drop(columns="index",inplace=True)

# %% [markdown]
# **2. SEGUNDO PASO:**
#  - Como veo que la columna "Totales Territoriales" no me va a ser útil, y se repite constantemente lo mismo, la elimino.
#  - Cambio los datos de la columna 'Comunidad Autónoma', para que en todas las filas ponga lo mismo: 'Madrid'

# %%
data.drop(columns="Totales Territoriales", inplace=True)

# %%
data.head()
# Out:
#         Comunidad Autónoma Viajeros o pernoctaciones            Residencia  \
# 0  13 Madrid, Comunidad de                   Viajero  Residentes en España
# 1  13 Madrid, Comunidad de                   Viajero  Residentes en España
# 2  13 Madrid, Comunidad de                   Viajero  Residentes en España
# 3  13 Madrid, Comunidad de                   Viajero  Residentes en España
# 4  13 Madrid, Comunidad de                   Viajero  Residentes en España
#
#    Periodo    Total
# 0  2023M09  564.048
# 1  2023M08  467.045
# 2  2023M07  563.343
# 3  2023M06  615.313
# 4  2023M05  567.870

# %%
data['Comunidad Autónoma'] = 'Madrid'

# %%
data.head()
# Out:
#   Comunidad Autónoma Viajeros o pernoctaciones            Residencia  Periodo  \
# 0             Madrid                   Viajero  Residentes en España  2023M09
# 1             Madrid                   Viajero  Residentes en España  2023M08
# 2             Madrid                   Viajero  Residentes en España  2023M07
# 3             Madrid                   Viajero  Residentes en España  2023M06
# 4             Madrid                   Viajero  Residentes en España  2023M05
#
#      Total
# 0  564.048
# 1  467.045
# 2  563.343
# 3  615.313
# 4  567.870

# %% [markdown]
# **3. TERCER PASO:**
# - Voy a separar la columna 'Viajeros o pernoctaciones' a dos columnas diferentes.
# - en el caso de poner 'viajero' parece que nunca existe 'pernoctaciones'. Por ello, decido que ponga Si o '', en el caso de que sea una u otra en su respectiva columna.

# %%
data['Viajeros'] = data['Viajeros o pernoctaciones'].apply(lambda x: 'Si' if 'Viajero' in x else '')
data['Pernoctaciones'] = data['Viajeros o pernoctaciones'].apply(lambda x: 'Si' if 'Pernoctaciones' in x else '')

# %%
data.drop(columns="Viajeros o pernoctaciones",inplace=True)

# %%
nuevo_orden = ['Comunidad Autónoma', 'Residencia', 'Viajeros', 'Pernoctaciones','Periodo', 'Total']

data = data[nuevo_orden]

# %%
data.head()
# Out:
#   Comunidad Autónoma            Residencia Viajeros Pernoctaciones  Periodo  \
# 0             Madrid  Residentes en España       Si                 2023M09
# 1             Madrid  Residentes en España       Si                 2023M08
# 2             Madrid  Residentes en España       Si                 2023M07
# 3             Madrid  Residentes en España       Si                 2023M06
# 4             Madrid  Residentes en España       Si                 2023M05
#
#      Total
# 0  564.048
# 1  467.045
# 2  563.343
# 3  615.313
# 4  567.870

# %% [markdown]
# **4. CUARTO PASO:**
# - La columna periodo contiene el 'mes' y el 'año'.
# - Genero dos nuevas columnas: 'mes' y 'año' en las que aparece el dato oportuno.
# - Elimino la columna 'periodo'.
# - Reordeno las columnas.

# %%
data['año'] = data['Periodo'].str[:4]
data['mes'] = data['Periodo'].str[5:]

# %%
data.drop(columns="Periodo",inplace=True)

# %%
nuevo_orden = ['Comunidad Autónoma', 'Residencia', 'Viajeros', 'Pernoctaciones','año', 'mes', 'Total']

data = data[nuevo_orden]

# %%
data.head()
# Out:
#   Comunidad Autónoma            Residencia Viajeros Pernoctaciones   año mes  \
# 0             Madrid  Residentes en España       Si                 2023  09
# 1             Madrid  Residentes en España       Si                 2023  08
# 2             Madrid  Residentes en España       Si                 2023  07
# 3             Madrid  Residentes en España       Si                 2023  06
# 4             Madrid  Residentes en España       Si                 2023  05
#
#      Total
# 0  564.048
# 1  467.045
# 2  563.343
# 3  615.313
# 4  567.870

# %%
nombres_nuevos = ['comunidad', 'residencia', 'viajeros', 'pernoctaciones', 'año', 'mes', 'total']

data.columns = nombres_nuevos

# %%
len(data)
# Out:
# 148

# %%
data.head()
# Out:
#   comunidad            residencia viajeros pernoctaciones   año mes    total
# 0    Madrid  Residentes en España       Si                 2023  09  564.048
# 1    Madrid  Residentes en España       Si                 2023  08  467.045
# 2    Madrid  Residentes en España       Si                 2023  07  563.343
# 3    Madrid  Residentes en España       Si                 2023  06  615.313
# 4    Madrid  Residentes en España       Si                 2023  05  567.870

# %% [markdown]
# **5. QUINTO PASO:**
#
# Voy a crear dos tablas diferentes:
# - 'residentes', compuesta por los 'Residentes en España'.
# - 'no_residentes', compuesta por aquellos 'Residentes en el Extranjero'.
# - Reseteo el index de las tablas y elimino la columna de 'index' que se genera.

# %%
# Hago un nuevo dataframe en el que filtro unicamente por aquellas personas que residen en España

residentes = data[data['residencia'] == 'Residentes en España']

# %%
residentes.head()
# Out:
#   comunidad            residencia viajeros pernoctaciones   año mes    total
# 0    Madrid  Residentes en España       Si                 2023  09  564.048
# 1    Madrid  Residentes en España       Si                 2023  08  467.045
# 2    Madrid  Residentes en España       Si                 2023  07  563.343
# 3    Madrid  Residentes en España       Si                 2023  06  615.313
# 4    Madrid  Residentes en España       Si                 2023  05  567.870

# %%
len(residentes)
# Out:
# 74

# %%
if 'mes' in residentes:
    residentes['mes'] = residentes['mes'].str.lstrip('0')

# %%
residentes.tail()
# Out:
#     comunidad            residencia viajeros pernoctaciones   año mes    total
# 106    Madrid  Residentes en España                      Si  2021   1  318.876
# 107    Madrid  Residentes en España                      Si  2020  12  358.265
# 108    Madrid  Residentes en España                      Si  2020  11  304.090
# 109    Madrid  Residentes en España                      Si  2020  10  273.851
# 110    Madrid  Residentes en España                      Si  2020   9  333.690

# %%
# Hago un nuevo dataframe en el que filtro unicamente por aquellas personas que no residen habitualmente en España

no_residentes = data[data['residencia'] == 'Residentes en el Extranjero']
no_residentes.head()
# Out:
#    comunidad                   residencia viajeros pernoctaciones   año mes  \
# 37    Madrid  Residentes en el Extranjero       Si                 2023  09
# 38    Madrid  Residentes en el Extranjero       Si                 2023  08
# 39    Madrid  Residentes en el Extranjero       Si                 2023  07
# 40    Madrid  Residentes en el Extranjero       Si                 2023  06
# 41    Madrid  Residentes en el Extranjero       Si                 2023  05
#
#       total
# 37  583.605
# 38  539.019
# 39  571.252
# 40  546.259
# 41  553.960

# %%
no_residentes.reset_index(inplace=True)

# %%
no_residentes.drop(columns="index",inplace=True)

# %%
if 'mes' in no_residentes:
    no_residentes['mes'] = no_residentes['mes'].str.lstrip('0')

# %%
no_residentes.head()
# Out:
#   comunidad                   residencia viajeros pernoctaciones   año mes  \
# 0    Madrid  Residentes en el Extranjero       Si                 2023   9
# 1    Madrid  Residentes en el Extranjero       Si                 2023   8
# 2    Madrid  Residentes en el Extranjero       Si                 2023   7
# 3    Madrid  Residentes en el Extranjero       Si                 2023   6
# 4    Madrid  Residentes en el Extranjero       Si                 2023   5
#
#      total
# 0  583.605
# 1  539.019
# 2  571.252
# 3  546.259
# 4  553.960

# %% [markdown]
# **6. SEXTO PASO:**
# - Importo mis tablas a .csv

# %% [markdown]
# Una vez he importado los dataframe como .csv los marco para que no se me vuelva a convertir.

# %%
#residentes.to_csv('residentes.csv', index=False)
#no_residentes.to_csv('no_residentes.csv', index=False)
